# %% [markdown]
# # Toutorial 3

# %% [markdown]
# ## 1. Integration

# %%
import numpy as np

def function(func_num, x):
    if func_num == 1:
        return np.sin(x)
    elif func_num == 2:
        return np.exp(-x)
    elif func_num == 3:
        return 1/(1+x*x)
    elif func_num == 4:
        return 1/x
    elif func_num == 5: 
        return np.sqrt(1 - 0.25 * (np.sin(x)**2))
    elif func_num == 6:
        return 1/(((np.sin(x)**2) + 0.25 * (np.cos(x)**2)))
    else:
        raise ValueError(f'No function defined for #{func_num}')

def integrate_trapezoidal(func_num, a, b, n):
    sum = 0
    points = np.linspace(a, b, n+1)
    #print(f"Points: {points}")
    for i, x in enumerate(points):
        func_value = function(func_num, x)
        if i != 0 and i != n:
            func_value *= 2

        sum += func_value
    
    return ((b-a)/(2*n))*sum

def integrate_simpson(func_num, a, b, n):
    if n % 2 != 0: raise ValueError('Need even intervals for Simpson method - {n} is not even')
    sum = 0
    points = np.linspace(a, b, n+1)
    for i, x in enumerate(points):
        func_value = function(func_num, x)
        if i > 0 and i < n:
            if i%2 != 0: func_value *= 4
            else: func_value *= 2

        sum += func_value
    
    return ((b-a)/(3*n))*sum

# test
func = 1
a = 0
b = np.pi/2
exact = 1
print(f"{func}, {a}, {b}, {exact}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 2):.2g}, simpson:{integrate_simpson(func, a, b, 2):.2g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 4):.2g}, simpson:{integrate_simpson(func, a, b, 4):.2g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 8):.2g}, simpson:{integrate_simpson(func, a, b, 8):.2g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 16):.2g}, simpson:{integrate_simpson(func, a, b, 16):.2g}")

print("#"*25)    

func = 2
a = 0
b = 2
exact = 0.86466
print(f"{func}, {a}, {b}, {exact}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 2):.6g}, simpson:{integrate_simpson(func, a, b, 2):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 4):.6g}, simpson:{integrate_simpson(func, a, b, 4):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 8):.6g}, simpson:{integrate_simpson(func, a, b, 8):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 16):.6g}, simpson:{integrate_simpson(func, a, b, 16):.6g}")

print("#"*25)    

func = 3
a = 0
b = 1
exact = np.pi/4
print(f"{func}, {a}, {b}, {exact}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 2):.6g}, simpson:{integrate_simpson(func, a, b, 2):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 4):.6g}, simpson:{integrate_simpson(func, a, b, 4):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 8):.6g}, simpson:{integrate_simpson(func, a, b, 8):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 16):.6g}, simpson:{integrate_simpson(func, a, b, 16):.6g}")

print("#"*25)    

func = 4
a = 1
b = 2
exact = np.log(2)
print(f"{func}, {a}, {b}, {exact}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 2):.6g}, simpson:{integrate_simpson(func, a, b, 2):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 4):.6g}, simpson:{integrate_simpson(func, a, b, 4):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 8):.6g}, simpson:{integrate_simpson(func, a, b, 8):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 16):.6g}, simpson:{integrate_simpson(func, a, b, 16):.6g}")

print("#"*25)    

func = 5
a = 0
b = np.pi/2
exact = 1.4675
print(f"{func}, {a}, {b}, {exact}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 2):.6g}, simpson:{integrate_simpson(func, a, b, 2):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 4):.6g}, simpson:{integrate_simpson(func, a, b, 4):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 8):.6g}, simpson:{integrate_simpson(func, a, b, 8):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 16):.6g}, simpson:{integrate_simpson(func, a, b, 16):.6g}")

print("#"*25)    

func = 6
a = 0
b = np.pi/2
exact = np.pi
print(f"{func}, {a}, {b}, {exact}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 2):.6g}, simpson:{integrate_simpson(func, a, b, 2):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 4):.6g}, simpson:{integrate_simpson(func, a, b, 4):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 8):.6g}, simpson:{integrate_simpson(func, a, b, 8):.6g}")
print(f"trapezoid:{integrate_trapezoidal(func, a, b, 16):.6g}, simpson:{integrate_simpson(func, a, b, 16):.6g}")

print("#"*25)
# Out:
# 1, 0, 1.5707963267948966, 1
# trapezoid:0.95, simpson:1
# trapezoid:0.99, simpson:1
# trapezoid:1, simpson:1
# trapezoid:1, simpson:1
# #########################
# 2, 0, 2, 0.86466
# trapezoid:0.935547, simpson:0.868951
# trapezoid:0.882604, simpson:0.864956
# trapezoid:0.869163, simpson:0.864683
# trapezoid:0.86579, simpson:0.864666
# #########################
# 3, 0, 1, 0.7853981633974483
# trapezoid:0.775, simpson:0.783333
# trapezoid:0.782794, simpson:0.785392
# trapezoid:0.784747, simpson:0.785398
# trapezoid:0.785235, simpson:0.785398
# #########################
# 4, 1, 2, 0.6931471805599453
# trapezoid:0.708333, simpson:0.694444
# trapezoid:0.697024, simpson:0.693254
# trapezoid:0.694122, simpson:0.693155
# trapezoid:0.693391, simpson:0.693148
# #########################
# 5, 0, 1.5707963267948966, 1.4675
# trapezoid:1.46746, simpson:1.46809
# trapezoid:1.46746, simpson:1.46746
# trapezoid:1.46746, simpson:1.46746
# trapezoid:1.46746, simpson:1.46746
# ...

# %% [markdown]
# ## 2. Iris scatter plot

# %%
import matplotlib.pyplot as plt
import pandas as pd

iris = pd.read_csv('iris.csv')

print(iris.head())



fig = plt.figure(figsize=(6,6))

for name, group in iris.groupby('species'):
    plt.scatter(group['petal-width'], group['petal-length'], label=name)

plt.xlabel('Petal width (cm)')
plt.ylabel('Petal length (cm)')
plt.legend(title='Species')
plt.show()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
